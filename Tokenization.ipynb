# %% [markdown]
# <a href="https://colab.research.google.com/github/jansoe/AIHorizons24/blob/main/Tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tokenization

# %%
import transformers
import torch

# %% [markdown]
# ## Tokenizer

# %%
model_version = 'gpt2'
tokenizer = transformers.AutoTokenizer.from_pretrained(model_version)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# ...

# %%
tokenizer.tokenize('This is a test of the tokenizer')
# Out:
# ['This', 'Ġis', 'Ġa', 'Ġtest', 'Ġof', 'Ġthe', 'Ġtoken', 'izer']

# %%
tokens = tokenizer('This is a test of the tokenizer')['input_ids']
tokens
# Out:
# [1212, 318, 257, 1332, 286, 262, 11241, 7509]

# %%
tokenizer.decode(tokens)
# Out:
# 'This is a test of the tokenizer'

# %%
tokenizer.tokenize('n0thing is corect')
# Out:
# ['n', '0', 'thing', 'Ġis', 'Ġcore', 'ct']

# %%
tokenizer.vocab
# Out:
# {'ĠRuntime': 43160,
#  '886': 44980,
#  'Ġaffirmed': 31036,
#  'ĠJou': 45538,
#  'ĠCALL': 42815,
#  'En': 4834,
#  'Ġongoing': 7044,
#  'ucci': 27501,
#  ']."': 29225,
#  'Ġmodernization': 49400,
#  '747': 48882,
#  'Ġcache': 12940,
#  'Ġtoxicity': 28152,
#  'ĠCanal': 31314,
#  'Ġvillage': 7404,
#  'ructure': 5620,
#  'Ġseamless': 32354,
#  'VERS': 28884,
#  'Ġintolerable': 49469,
#  'avia': 40543,
#  'Ġlock': 5793,
#  'Box': 14253,
#  'ĠDA': 17051,
#  'Clock': 44758,
#  'Ġtet': 28408,
#  'Ġstre': 1937,
#  'Ġclimate': 4258,
#  '...)': 23029,
#  'ĠMY': 17615,
#  'Ġgrazing': 40470,
#  'Ġconflicted': 46060,
#  'stros': 48288,
#  'abet': 8380,
#  'ĠFormula': 19639,
#  '170': 17279,
#  'cake': 30560,
#  'Ġcourier': 48934,
#  'Ġheav': 6002,
#  'Ġforum': 10041,
#  'Ġnegotiator': 49194,
#  'laden': 35668,
#  'credit': 43082,
#  'Ġquitting': 34161,
#  'Ġtruthful': 42278,
#  'Ġ209': 28815,
#  'Ġmin': 949,
#  'udget': 29427,
#  'ĠSinclair': 34927,
#  'ĠFriedrich': 46099,
# ...

# %% [markdown]
# ### Test of different tokenizer
#
# Possible models:
# * https://huggingface.co/models?pipeline_tag=text-classification&sort=downloads

# %% [markdown]
# #### Task:
# Use the current tokenzizer to tokenize some spanish sentences. Then look for a spanish model and compare the tokenization results
